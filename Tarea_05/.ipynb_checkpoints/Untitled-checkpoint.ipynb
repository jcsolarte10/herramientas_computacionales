# %%
# %pylab inline
import cv2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e28b77108d96> in <module>()
#       1 get_ipython().magic('pylab inline')
# ----> 2 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
ves = ndimage.imread('./ves_full.jpg', mode = 'F')
plt.imshow(ves, cmap = cm.gray)
plt.show()

# %%
denoised = ndimage.gaussian_filter(ves,2)
distance = ndimage.distance_transform_edt(denoised)
local_maxi = feature.peak_local_max(distance, indices=False)
markers = ndimage.label(local_maxi)[0]
labels = watershed(-distance, markers, mask=denoised)

# %%
imshow(labels, cmap=plt.cm.nipy_spectral, interpolation='nearest')
