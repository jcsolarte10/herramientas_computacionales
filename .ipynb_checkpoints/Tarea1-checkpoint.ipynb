# %%
import os
import pandas as pd
import statistics as st
import matplotlib.pyplot as plt
import scipy.stats as scp
import numpy as np

# %%
## Funciones

def ghi_mensual(serie_horaria):
    agnos = sorted(serie_horaria['AÑO'].unique())
    ghi_df = pd.DataFrame(columns=["AÑO", "MES", "DIAS", "GHImes"])
    for agno in agnos:
        for mes in range(1,13):
            nombre_energia = list(serie_horaria)[-1]
            dias = sorted(serie_horaria[(serie_horaria['AÑO'] == agno) &
                        (serie_horaria['MES'] == mes)]["DIA"].unique())
            ghi_mes = serie_horaria.loc[((serie_horaria["AÑO"] == agno)
                            & (serie_horaria["MES"] == mes)),
                                        nombre_energia].sum()/1000
            ghi_dict = {"AÑO":agno, "MES":mes, "DIAS":dias[-1],
                        "GHImes":ghi_mes}
            ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
    return ghi_df

def ghi_dia(serie_ghi_mensual):
    agnos = sorted(serie_ghi_mensual['AÑO'].unique())
    ghi_df = pd.DataFrame(columns=["AÑO", "MES", "GHIdiario"])
    for agno in agnos:
        for mes in range(1,13):
            dias = serie_ghi_mensual.loc[((serie_ghi_mensual["AÑO"] == agno)
                            & (serie_ghi_mensual["MES"] == mes))
                                         ,"DIAS"].item()
            ghi_diario = serie_ghi_mensual.loc[(
                (serie_ghi_mensual["AÑO"] == agno)
                            & (serie_ghi_mensual["MES"] == mes)),
                "GHImes"].item()/dias
            ghi_dict = {"AÑO":agno, "MES":mes, "GHIdiario":ghi_diario}
            ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
    return ghi_df

def extraer_datos(fuente, ciudad,agno_in):
    base_dir = os.path.join( '.',os.path.join( '02_taller01','data')) 
    output_dir = os.path.join( '.','output')
    serie_csv = os.path.join(base_dir,ciudad,fuente+'.csv')
    serie_pd = pd.read_csv(serie_csv, sep = ';',
                encoding='latin-1')
    serie_pd = serie_pd.sort_values(['AÑO','MES','DIA','HORA'])
    
    if agno_in != 0:
        serie_pd =  serie_pd[(serie_pd.AÑO)>=agno_in]
    
    return serie_pd

def enficc(datos):
    ghi_mensual_loc = ghi_mensual(datos)
    ghi_diario_loc = ghi_dia(ghi_mensual_loc)
    enficc = ghi_diario_loc.quantile(q=0.1, 
                                 numeric_only=True)["GHIdiario"]
    return enficc
    
def ajustar_datos(corta, NREL, nrel_truncada):
    """Corta en array y larga en df"""
    
    larga= NREL.NREL
    sigma_corta = st.stdev(corta)
    sigma_larga = st.stdev(nrel_truncada)
    prom_corta = st.mean(corta)
    prom_larga = st.mean(nrel_truncada)
    ajustada = (prom_corta-(sigma_corta/sigma_larga)*prom_larga)+(sigma_corta/sigma_larga)*larga
    d = {"AÑO":NREL.AÑO, "MES":NREL.MES, "DIA":NREL.DIA, "HORA":NREL.HORA,"IDEAM":ajustada}
    datos = pd.DataFrame(data=d)
    datos=datos[["AÑO","MES", "DIA", "HORA","IDEAM"]]
    
    
    
    return datos

def grafica_norma(ideam,nrel,ajst,nombre,agno):
    """Entran los df en resolución horaria de las radiciaciones para IDEAM, NREL y Ajustada, respectivamente """
    
    output_dir = os.path.join( '.')
    
    y_IDEAM= sorted(ghi_dia(ghi_mensual(ideam)).GHIdiario)
    y_min = y_IDEAM[0]
    y_IDEAM = y_IDEAM/y_min
    y_NREL= sorted(ghi_dia(ghi_mensual(nrel)).GHIdiario)/y_min
    y_AJST= sorted(ghi_dia(ghi_mensual(ajst)).GHIdiario)/y_min
    x_1 = range(len(y_IDEAM))
    x_2 = range(len(y_NREL))
    plt.xlabel("Datos")
    plt.ylabel("Energía/Energía Base IDEAM")
    plt.plot(x_1,y_IDEAM,label = "IDEAM")
    plt.plot(x_2,y_NREL, label = "NREL")
    plt.plot(x_2,y_AJST, label="Ajustada")
    plt.legend(loc='upper left')
    plt.savefig(os.path.join(output_dir,nombre+ str(agno) +'.png'), dpi=600)
    plt.show()
    
def error_enficc(ref,comp):
    e_1 = enficc(ref)
    e_2 = enficc(comp)
    error = abs(e_1-e_2)/e_1 *100
    
    return error

def rmsen(ref,comp):
    r = np.array(ref)
    c = np.array(comp)
    rmsd = np.sqrt(sum((c-r)**2)/len(r))
    ans = rmsd/(max(c)-min(c))
    
    return ans

def mbe(ref,comp):
    r = np.array(ref)
    c = np.array(comp)
    
    ans= sum(r-c)/sum(c)
    
    return ans
    
    
def errores(ref,comp):
    """El primero es el valor de referencia y el segundo el que se quiere evaluar"""
    
    ref_GHI= ghi_dia(ghi_mensual(ref)).sort_values(['AÑO','MES']).GHIdiario
    comp_GHI= ghi_dia(ghi_mensual(comp)).sort_values(['AÑO','MES']).GHIdiario
    error_1 = error_enficc(ref,comp)
    error_2 = rmsen(ref_GHI,comp_GHI)
    error_3 = mbe(ref_GHI,comp_GHI)
    ks_pvalue = scp.ks_2samp(ref_GHI,comp_GHI).pvalue
    
    print("\n"+'El error en el calculo de la ENFICC es: ' , error_1, "%")
    print("\n"+'El error NRMSE es: ' , error_2)
    print("\n"+'El error MBE es: ' , error_3)
    print("\n"+"El p-value de KS para las 2 series de datos es: ",ks_pvalue)
    
def recortar(datos,agno_in,agno_fin,mes_in,mes_fin):
    if agno_in<min(datos.AÑO):
        print("Elige un año inicial mayor")
    
    if agno_fin>max(datos.AÑO):
        print("Elige un año final menor")
        
    if agno_fin<agno_in or mes_fin<mes_in:
        print("La escogencia de años o meses es errada")
    
    else:
        if agno_in == agno_fin:
            ans = datos[(datos.AÑO == agno_in) & (datos.MES >= mes_in) & (datos.MES <= mes_fin)]
            return ans
    
        else:
            ans = datos[(datos.AÑO >= agno_in) & (datos.AÑO <= agno_fin)]
            return ans

# %%
ct = ["Cali","Barranquilla","Carmendebolivar","Medellin","SantaMarta","Sucre","Uribia", "Valledupar"]

# %%
ciudad = "Cali"
m_end = 12
agno = [2011,2015]
print("\n"+ciudad, ",", str(agno[1])+ "-" +str(m_end))
IDEAM_ciudad = extraer_datos('IDEAM',ciudad,0)
NREL_ciudad = extraer_datos('NREL',ciudad,min(IDEAM_ciudad.AÑO))
IDEAM = recortar(IDEAM_ciudad,agno[0],agno[1],1,m_end)
IDEAM = IDEAM.IDEAM
NREL = NREL_ciudad
ajst = ajustar_datos(IDEAM,NREL,recortar(NREL,agno[0],agno[1],1,m_end).NREL)
grafica_norma(IDEAM_ciudad,NREL_ciudad,ajst,ciudad,str(agno[1]) + "-" +str(m_end))
print("Sin ajustar")
errores(IDEAM_ciudad,NREL_ciudad)
print("Ajustada")
errores(IDEAM_ciudad,ajst)
# Out:
# Cali , 2015-12
# Sin ajustar
#
# El error en el calculo de la ENFICC es:  22.3593738102 %
#
# El error NRMSE es:  0.461503444136
#
# El error MBE es:  -0.161772459185
#
# El p-value de KS para las 2 series de datos es:  1.81891453746e-28
# Ajustada
#
# El error en el calculo de la ENFICC es:  2.2205752965 %
#
# El error NRMSE es:  0.157457502646
#
# El error MBE es:  0.000231700866969
#
# El p-value de KS para las 2 series de datos es:  0.606668396628

# %% [markdown]
# <h1><center>Analisis de ajuste de GHI para calculo de ENFICC</center></h1>
# <h2><center>Juan Carlos Solarte M.</center></h2>
# <h2><center>Febrero 2018</center></h2>
#
#
# ## Descripción
# El siguiene trabajo evaluar la efectividad del método MCP para el ajuste de datos satlitales de radiación solar con base a información tomada en campo. Lo anterior, se hara considerando diferentes escenarios de información inperfecta para la alimentación del ajuste.
#
# Con el fin de hacer en analisis se plantearon 3 escenarios.
# 1. Ajuste de datos con información de 2010 (primer año en que coinciden los datos de IDEAM de todas la ciudades) para cada ciudad
# 2. Ajuste de datos con información de año escogido aleatoriamente para cada ciudad
# 3. Ajuste de datos de Cali (ciudad con mayor error previo ajuste) para diferentes longitudes de tiempo
#
# Para observar el efecto del ajuste se tomaron 4 indicadores de error:
# 1. Medición de discrepancia entre ENFICC99 calculada con datos de IDEAM y NREL con y sin ajuste
# 2. Error NRMSE entre datos de IDEAM y NREL con y sin ajuste
# 3. Error MBE entre datos de IDEAM y NREL con y sin ajuste
# 4. P-Value de prueba de correlación entre datos de IDEAM y y NREL con y sin ajuste
#
# Fe de errata: La dicrepancia de **ENFICC99** se reporto como error en calculo de **ENFICC**
#
#
# <br> <br>
# ***
# ***
# <br> <br>
#
# ## Ciudades para 2010
#
# ##  Cali
#
#
# ![logo](./Cali2010.png)
# **Figura 1: Distribución de GHI de Cali para distintas series**
#
# <br> <br>
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  22.3593738102 %
#
# El error NRMSE es:  0.461503444136
#
# El error MBE es:  -0.161772459185
#
# El p-value de KS para las 2 series de datos es:  1.81891453746e-28
#
#
# ### Ajustada
# El error en el calculo de la ENFICC es:  0.638033744719 %
#
# El error NRMSE es:  0.164656975654
#
# El error MBE es:  0.0157199894209
#
# El p-value de KS para las 2 series de datos es:  0.0890858229024
#
# ***
#
# ##  Barranquilla
#
# ![logo](./Barranquilla2010.png)
#
# **Figura 2: Distribución de GHI de Barranquilla para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  13.1028603224 %
#
# El error NRMSE es:  0.263515297779
#
# El error MBE es:  -0.0357639454867
#
# El p-value de KS para las 2 series de datos es:  0.00596686064723
#
#
# ### Ajustada
# El error en el calculo de la ENFICC es:  11.6048938478 %
#
# El error NRMSE es:  0.255720044387
#
# El error MBE es:  -0.0235941180743
#
# El p-value de KS para las 2 series de datos es:  0.0759510717332
#
# ***
#
# ##  Carmen de Bolivar
#
# ![logo](./Carmendebolivar2010.png)
#
# **Figura 3: Distribución de GHI de Carmen de Bolivar para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  6.91549213381 %
#
# El error NRMSE es:  0.27112319705
#
# El error MBE es:  -0.0349607475339
#
# El p-value de KS para las 2 series de datos es:  0.00792367850338
#
#
# ### Ajustada
# El error en el calculo de la ENFICC es:  18.2761951323 %
#
# El error NRMSE es:  0.376087207881
#
# El error MBE es:  -0.128276345226
#
# El p-value de KS para las 2 series de datos es:  1.87102895736e-14
#
# ***
#
# ##  Medellin
#
# ![logo](./Medellin2010.png)
#
# **Figura 4: Distribución de GHI de Medellin para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  21.5062688918 %
#
# El error NRMSE es:  0.362636102534
#
# El error MBE es:  -0.164792860479
#
#
#
# ### Ajustada
#
# El error en el calculo de la ENFICC es:  0.566627898044 %
#
# El error NRMSE es:  0.171995994761
#
# El error MBE es:  0.0193995279585
#
# El p-value de KS para las 2 series de datos es:  0.165311302375
#
# ***
#
# ##  Santa Marta
#
# ![logo](./SantaMarta2010.png)
#
# **Figura 5: Distribución de GHI de Santa Marta para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
#
# El error en el calculo de la ENFICC es:  10.0565943359 %
#
# El error NRMSE es:  0.206138776489
#
# El error MBE es:  -0.0404650895271
#
# El p-value de KS para las 2 series de datos es:  0.0168642850741
#
#
# ### Ajustada
#
#
# El error en el calculo de la ENFICC es:  1.12428448677 %
#
# El error NRMSE es:  0.252886326653
#
# El error MBE es:  0.0665154748966
#
# El p-value de KS para las 2 series de datos es:  0.00074555357364
#
# ***
#
# ##  Sucre
#
# ![logo](./Sucre2010.png)
#
# **Figura 6: Distribución de GHI de Sucre para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
#
# El error en el calculo de la ENFICC es:  19.4800548043 %
#
# El error NRMSE es:  0.615025248971
#
# El error MBE es:  -0.148199498661
#
# El p-value de KS para las 2 series de datos es:  8.40753654636e-24
#
#
# ### Ajustada
#
# El error en el calculo de la ENFICC es:  5.43288019629 %
#
# El error NRMSE es:  0.42273377647
#
# El error MBE es:  -0.038487934094
#
# El p-value de KS para las 2 series de datos es:  0.219571571973
#
# ***
#
# ## Uribia
#
# ![logo](./Uribia2010.png)
#
# **Figura 7: Distribución de GHI de Uribia para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  7.39973090971 %
#
# El error NRMSE es:  0.220773781346
#
# El error MBE es:  -0.0751719060362
#
# El p-value de KS para las 2 series de datos es:  1.01078107456e-06
# Ajustada
#
# El error en el calculo de la ENFICC es:  3.22173751209 %
#
# El error NRMSE es:  0.166027289512
#
# El error MBE es:  0.0208652142825
#
# El p-value de KS para las 2 series de datos es:  0.0445872330161
#
#
# ### Ajustada
#
# El error en el calculo de la ENFICC es:  3.22173751209 %
#
# El error NRMSE es:  0.166027289512
#
# El error MBE es:  0.0208652142825
#
# El p-value de KS para las 2 series de datos es:  0.04458723301
#
# ***
#
# ##  Valledupar
#
# ![logo](./Valledupar2010.png)
#
# **Figura 8: Distribución de GHI de Valledupar para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  14.7106265856 %
#
# El error NRMSE es:  0.361863879712
#
# El error MBE es:  -0.103215126141
#
# El p-value de KS para las 2 series de datos es:  7.65209046374e-20
#
#
# ### Ajustada
#
#
# El error en el calculo de la ENFICC es:  0.559008276591 %
#
# El error NRMSE es:  0.224189206932
#
# El error MBE es:  0.0310905382914
#
# El p-value de KS para las 2 series de datos es:  0.0208737765571
#
# <br> <br>
# <br> <br>
#
# ## Ciudades para distintos años
#
# ##  Cali (2014)
#
#
# ![logo](./Cali2014.png)
# **Figura 9: Distribución de GHI de Cali para distintas series**
#
# <br> <br>
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  22.3593738102 %
#
# El error NRMSE es:  0.461503444136
#
# El error MBE es:  -0.161772459185
#
# El p-value de KS para las 2 series de datos es:  1.81891453746e-28
#
#
# ### Ajustada
# El error en el calculo de la ENFICC es:  4.75148075138 %
#
# El error NRMSE es:  0.166398412774
#
# El error MBE es:  -0.0238130442366
#
# El p-value de KS para las 2 series de datos es:  0.0624499367622
#
# ***
#
# ##  Barranquilla (2013)
#
# ![logo](./Barranquilla2013.png)
#
# **Figura 10: Distribución de GHI de Barranquilla para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  13.1028603224 %
#
# El error NRMSE es:  0.263515297779
#
# El error MBE es:  -0.0357639454867
#
# El p-value de KS para las 2 series de datos es:  0.00596686064723
#
#
# ### Ajustada
# El error en el calculo de la ENFICC es:  8.94720342259 %
#
# El error NRMSE es:  0.249383505033
#
# El error MBE es:  -0.0022088559511
#
# El p-value de KS para las 2 series de datos es:  0.171326232475
#
# ***
#
# ##  Carmen de Bolivar (2013)
#
# ![logo](./Carmendebolivar2010.png)
#
# **Figura 11: Distribución de GHI de Carmen de Bolivar para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  6.91549213381 %
#
# El error NRMSE es:  0.27112319705
#
# El error MBE es:  -0.0349607475339
#
# El p-value de KS para las 2 series de datos es:  0.00792367850338
#
#
# ### Ajustada
# El error en el calculo de la ENFICC es:  8.94439785993 %
#
# El error NRMSE es:  0.392888393339
#
# El error MBE es:  0.126826455882
#
# El p-value de KS para las 2 series de datos es:  1.22686762951e-09
#
# ***
#
# ##  Medellin (2012)
#
# ![logo](./Medellin2012.png)
#
# **Figura 12: Distribución de GHI de Medellin para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  21.5062688918 %
#
# El error NRMSE es:  0.362636102534
#
# El error MBE es:  -0.164792860479
#
#
#
# ### Ajustada
#
#
# El error en el calculo de la ENFICC es:  4.09031102153 %
#
# El error NRMSE es:  0.195408470055
#
# El error MBE es:  0.0522744372302
#
# El p-value de KS para las 2 series de datos es:  0.00141569840521
#
# ***
#
# ##  Santa Marta (2011)
#
# ![logo](./SantaMarta2011.png)
#
# **Figura 13: Distribución de GHI de Santa Marta para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
#
# El error en el calculo de la ENFICC es:  10.0565943359 %
#
# El error NRMSE es:  0.206138776489
#
# El error MBE es:  -0.0404650895271
#
# El p-value de KS para las 2 series de datos es:  0.0168642850741
#
#
# ### Ajustada
#
#
# El error en el calculo de la ENFICC es:  4.23987132356 %
#
# El error NRMSE es:  0.1989432663
#
# El error MBE es:  0.0138949951913
#
# El p-value de KS para las 2 series de datos es:  0.416611448045
#
# ***
#
# ##  Sucre (2013)
#
# ![logo](./Sucre2013.png)
#
# **Figura 14: Distribución de GHI de Sucre para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
#
# El error en el calculo de la ENFICC es:  19.4800548043 %
#
# El error NRMSE es:  0.615025248971
#
# El error MBE es:  -0.148199498661
#
# El p-value de KS para las 2 series de datos es:  8.40753654636e-24
#
#
# ### Ajustada
#
#
# El error en el calculo de la ENFICC es:  3.96746107333 %
#
# El error NRMSE es:  0.414434960645
#
# El error MBE es:  -0.0259025367843
#
# El p-value de KS para las 2 series de datos es:  0.56375680682
#
# ***
#
# ## Uribia (2011)
#
# ![logo](./Uribia2011.png)
#
# **Figura 15: Distribución de GHI de Uribia para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  7.39973090971 %
#
# El error NRMSE es:  0.220773781346
#
# El error MBE es:  -0.0751719060362
#
# El p-value de KS para las 2 series de datos es:  1.01078107456e-06
#
#
# ### Ajustada
#
#
# El error en el calculo de la ENFICC es:  1.77140039875 %
#
# El error NRMSE es:  0.159788859176
#
# El error MBE es:  0.00604235277537
#
# El p-value de KS para las 2 series de datos es:  0.219571571973
#
# ***
#
# ##  Valledupar (2012)
#
# ![logo](./Valledupar2012.png)
#
# **Figura 16: Distribución de GHI de Valledupar para distintas series**
#
# <br> <br>
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  14.7106265856 %
#
# El error NRMSE es:  0.361863879712
#
# El error MBE es:  -0.103215126141
#
# El p-value de KS para las 2 series de datos es:  7.65209046374e-20
#
#
# ### Ajustada
#
#
# El error en el calculo de la ENFICC es:  1.93477520398 %
#
# El error NRMSE es:  0.243469329865
#
# El error MBE es:  0.044903311225
#
# El p-value de KS para las 2 series de datos es:  0.000851098187747
#
#
# <br> <br>
# ***
# ***
# <br> <br>
#
# ## Cali para distintas longitudes de tiempo en 2013
#
#
# ### Sin ajustar
#
# El error en el calculo de la ENFICC es:  21.5062688918 %
#
# El error NRMSE es:  0.362636102534
#
# El error MBE es:  -0.164792860479
#
# El p-value de KS para las 2 series de datos es:  1.81891453746e-28
#
# ***
#
#
# ##  Cali (3 meses)
#
# ![logo](./Cali2013-3.png)
#
# **Figura 17: Distribución de GHI de Cali para distintas series**
#
# <br> <br>
#
#
#
# ### Ajustada
#
# El error en el calculo de la ENFICC es:  5.5828019936 %
#
# El error NRMSE es:  0.286585858875
#
# El error MBE es:  0.084856351554
#
# El p-value de KS para las 2 series de datos es:  2.99665864567e-09
#
# ***
#
# ##  Cali (6 meses)
#
# ![logo](./Cali2013-6.png)
#
# **Figura 18: Distribución de GHI de Cali para distintas series**
#
# <br> <br>
#
# ### Ajustada
#
# El error en el calculo de la ENFICC es:  2.96088711888 %
#
# El error NRMSE es:  0.221145444849
#
# El error MBE es:  0.0545050417996
#
# El p-value de KS para las 2 series de datos es:  7.87585967898e-06
#
# ***
#
# ##  Cali (12 meses)
#
# ![logo](./Cali2013-12.png)
#
# **Figura 19: Distribución de GHI de Cali para distintas series**
#
# <br> <br>
#
#
# ### Ajustada
#
# El error en el calculo de la ENFICC es:  0.812087524194 %
#
# El error NRMSE es:  0.166637335982
#
# El error MBE es:  0.0153366903496
#
# El p-value de KS para las 2 series de datos es:  0.0890858229024
#
# ##  Cali (4 años)
#
# ![logo](./Cali2015-12.png)
#
# **Figura 20: Distribución de GHI de Cali para distintas series**
#
# <br> <br>
#
#
# ### Ajustada
#
# El error en el calculo de la ENFICC es:  2.2205752965 %
#
# El error NRMSE es:  0.157457502646
#
# El error MBE es:  0.000231700866969
#
# El p-value de KS para las 2 series de datos es:  0.606668396628
#
# <br> <br>
# ***
# ***
# <br> <br>
#
# ## Conclusiones
#
#
# A partir de los observado de las gráficas e indicadores de error de las gráficas, se puede decir que, primero, el método demuestra ser efectivo en ajustar los datos satlitales a los medidos en tierra, ya que para todas las ciudades (excepto Carmen de Bolivar) , independiente del año, fue capaz de reducir los errores y mejorar la correlaciones. Segundo, el método es más efectivo  para los casos en que inicialmente los datos satelitales se encontraban más alejados de los tomados en tierra, por ejemplo, los ajustes de Cali y Barranquilla generan mejores resultados que los de Barranquilla y Carmen de Bolivar; inclusive, en casos como los de Carmen de Bolivar, donde por lo menos cualitativamente, se observa una distribución muy similar del GHI para los datos de IDEAM y NREL, se recomienda hacer ajuste con periodos mayores a 1 año para evitar que los datos se alejen de los de IDEAM durante el ajuste. Tercero, los ajustes si s ven afectados por el año escogido para hacerlos, al comparar los resultados de 2010 con los de otro año para cada una de las ciudades se vio que los resultados variraron, siendo el caso de Barranquilla el más ilustrativo ya que en este caso se vio una mejora significativamente en el ajuste al escoger los datos de 2013 en vez de los de 2010. Y cuarto, que al aumentar la longitud de la muestra de datos tomados en tierra mejora el ajuste, siendo muy poco recomendable hacer un ajuste con un periodo de tiempo menor a un año. En el ajuste de Cali con diferente número de mese, se observa una mejora sostenida de los indicadores a medida que se aumenta la longitud de la muestra de los datos en tierra; cabe hacer la salvedad, para el caso de Cali al escoger un periodo mayor a 1 año, el unico indicador que mejorar es el p-value de la prueba de correlación.
