# %%
import scipy as sc
import numpy as np
import matplotlib.pyplot as pplot

# %%
a= np.linspace(0,20,20)
b= np.logspace(20,10,20)

# %%
f=sc.interpolate.Akima1DInterpolator(a,b)
x= np.linspace(0,10,100)
y= f(x)
pplot.plot(x,y, a,b)
pplot.show()
