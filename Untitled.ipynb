# %%
from scipy import signal
from scipy import ndimage
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as intgr

# %%
a= np.linspace(0,30,100)
a= a + np.random.normal(0.75,5,100)
b = signal.wiener(a)
c = ndimage.gaussian_filter(a,sigma=5)
f= [a,0]
i = intgr.
plt.plot(a)
plt.plot(b)
plt.plot(c)
plt.show()
